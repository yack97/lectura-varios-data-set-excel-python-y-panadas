# %% [markdown]
# <a href="https://colab.research.google.com/github/yack97/lectura-varios-data-set-excel-python-y-panadas/blob/main/Lectura_de_varios_documentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob as glob

# %%
tmp = []

for i in glob.glob ("*.xlsx"):
    df = pd.read_excel(i)
    tmp.append(pd.read_excel(i))

df = pd.concat(tmp)
df
# Out:
#       MOC_RUBROS_ID  MOC_ZONAS_ID                  RUBRO  NIVEL_RIESGO  \
# 0               1.0             1  INSUMOS PARA EL HOGAR           5.0
# 1               2.0             2  INSUMOS PARA EL HOGAR           NaN
# 2               3.0             3  INSUMOS PARA EL HOGAR           1.0
# 3               4.0             4  INSUMOS PARA EL HOGAR           1.0
# 4               5.0             5  INSUMOS PARA EL HOGAR           NaN
# ...             ...           ...                    ...           ...
# 3109            NaN            67            VETERINARIA           NaN
# 3110            NaN            92            VETERINARIA           NaN
# 3111            NaN            95            VETERINARIA           NaN
# 3112            NaN           117            VETERINARIA           NaN
# 3113            NaN           161            VETERINARIA           NaN
#
#       FACTURACION_PROM_ACTUAL  INDICE_CRECIMIENTO  INDICE_ESTABILIDAD  \
# ...
